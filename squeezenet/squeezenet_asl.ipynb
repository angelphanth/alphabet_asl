# %% [markdown]
# # Training `SqueezeNet` to Classify ASL Letters
#
# In this notebook we will be training the [SqueezeNet](https://github.com/forresti/SqueezeNet) Convolutional Neural Network (CNN) created by [Forrest Iandola and colleagues](https://arxiv.org/abs/1602.07360) on the [ASL alphabet images](https://www.kaggle.com/grassknoted/asl-alphabet) preprocessed and organized using [<b><i>split_only_asl.sh</i></b>](https://github.com/angelphanth/alphabet_asl/blob/master/data_augmentation/split_only_asl.sh) and [<b><i>bright_images.py</i></b>](https://github.com/angelphanth/alphabet_asl/blob/master/data_augmentation/bright_images.py).
#
# ### Keras-SqueezeNet
#
# SqueezeNet will be implemented using [`keras_squeezenet`](https://github.com/rcmalli/keras-squeezenet)created by [Refik Can Malli](https://github.com/rcmalli).
#
# Currently, `keras_squeezenet` is compatible with **Keras v2.1.1** and **Tensorflow v1.4**, and can be installed via `pip install keras_squeezenet`.
#
# As we are using **Keras-GPU v2.3.1** and **Tensorflow-GPU v2.1.0** we will need to slightly alter the <b><i>squeezenet.py</i></b> file in our environment (e.g. 'C:/Users/*your_username*/Anaconda3/envs/*your_environment*/lib/site-packages/keras_squeezenet/squeezenet.py' ):
#
# - Replace `from keras.applications.imagenet_utils import _obtain_input_shape` with
#
# `from keras_applications.imagenet_utils import _obtain_input_shape`
#
# and
#
# - Remove `warnings` in `from keras.layers import ...`.
#
# **Model Evaluation**
#
# SqueezeNet model performance when classifying the existing test images will then be evaluated using `sklearn.metrics.classification_report` and `confusion_matrix`.
#
# Model performance on real-time images will similarly be evaluated in: [<b><i>evaluate_live_all.py</i></b>](https://github.com/angelphanth/alphabet_asl/blob/master/evaluate_live_all.py).

# %%
# Importing the usual libraries 
import pandas as pd
import numpy as np

# Importing rcmalli's keras-squeezenet
from keras_squeezenet import SqueezeNet

# Model Configuration 
from keras.layers import Dense, Dropout, Activation
from keras.activations import relu
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Model, model_from_json, Sequential
from keras.optimizers import Adam
from keras.utils import plot_model

# Model Evaluation
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Why SqueezeNet?
# SqueezeNet was selected for its compact ([less parameters](https://towardsdatascience.com/review-squeezenet-image-classification-e7414825581a)), while still powerful punch when given image classification tasks.
#
# Despite having under one million parameters (that's [50x fewer parameters than AlexNet!](https://arxiv.org/abs/1602.07360)), SqueezeNet delivers accuracy comparable to AlexNet on computer vision tasks.
#
# **Why "Less is More"**
#
# - Fewer parameters helps us to prevent [vanishing gradients](https://towardsdatascience.com/the-vanishing-gradient-problem-69bf08b15484) during backpropagation.
#
# - Like the rationale for transfer learning, we cut down on computational and time demands when we have less trainable parameters.
#
# - Further, more compact models ([SqueezeNet is < 0.5MB in size](https://arxiv.org/abs/1602.07360)) will deliver quicker predictions when implemented in apps. This speed element is key for the final goal of **predicting ASL letters in real-time**.
#
# -------
#
# Transfer learning was configured using the following Medium articles written by [Parkash Jay](https://medium.com/@14prakash/transfer-learning-using-keras-d804b2e04ef8) and [James Le](https://towardsdatascience.com/the-4-convolutional-neural-network-models-that-can-classify-your-fashion-images-9fe7f3e5399d).
#
# SqueezeNet will be trained on 80% of the ASL alphabet images preprocessed using [<b><i>split_only_asl.sh</i></b>](https://github.com/angelphanth/alphabet_asl/blob/master/data_augmentation/split_only_asl.sh) and [<b><i>bright_images.py</i></b>](https://github.com/angelphanth/alphabet_asl/blob/master/data_augmentation/bright_images.py). To review, the dataset of square (200 `pixels` by 200 pixels), colour (3 `channels`) images contains 29 `classes`.
#
# The images will be fed into the `model` in `batch_size`s of 40. An iterative process, each batch is considered a bout of learning where given the model's performance on that batch its trainable parameters will be tweaked in an attempt to minimize the amount of error (or `categorical_crossentropy`) on the next batch of images.
#
# Once the model has seen all the images in the dataset via **X** number of batches/`steps` then the model has completed one **epoch**. The model will undergo a minimum of `12` and a maximum of `30` epochs.

# %%
# Saving variables that will be called upon throughout the notebook 
classes = 29 
pixels = 200
channels = 3 
path = '../brighten_only/'
batch_size = 40

# Training the model for a minimum of 12 and maximum of 30 epochs
min_epochs=12
epochs=30

# Initialize the model 
model = Sequential()

# %% [markdown]
# The first 20% of SqueezeNet's layers will not be trainable on the ASL dataset. By leveraging transfer learning this will further cut down on the number of parameters that need to be trained.

# %%
# Import SqueezeNet architecture with weights trained on 'imagenet', do not include the top layers
pretrained = SqueezeNet(weights='imagenet', include_top=False, pooling='avg', input_shape=(pixels,pixels,channels))

# Total layers
total_layers = len(pretrained.layers)

# 20% of layers
no_train_layers = int(total_layers *0.2)

# Sanity check 
print(f'The first {no_train_layers} will not be trainable.')
# Out:
# The first 12 will not be trainable.

# %%
# Setting the first few layers to NOT trainable so weights won't be tweaked
for layer in pretrained.layers[:no_train_layers]:
    layer.trainable=False
    
# Allow all other layers to be trained on the ASL images    
for layer in pretrained.layers[no_train_layers:]:
    layer.trainable=True
    
# Display SqueezeNet architecture
pretrained.summary()
# Out:
# Model: "squeezenet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 200, 200, 3)  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 99, 99, 64)   1792        input_1[0][0]
# __________________________________________________________________________________________________
# relu_conv1 (Activation)         (None, 99, 99, 64)   0           conv1[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 49, 49, 64)   0           relu_conv1[0][0]
# __________________________________________________________________________________________________
# fire2/squeeze1x1 (Conv2D)       (None, 49, 49, 16)   1040        pool1[0][0]
# __________________________________________________________________________________________________
# fire2/relu_squeeze1x1 (Activati (None, 49, 49, 16)   0           fire2/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire2/expand1x1 (Conv2D)        (None, 49, 49, 64)   1088        fire2/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire2/expand3x3 (Conv2D)        (None, 49, 49, 64)   9280        fire2/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire2/relu_expand1x1 (Activatio (None, 49, 49, 64)   0           fire2/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire2/relu_expand3x3 (Activatio (None, 49, 49, 64)   0           fire2/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire2/concat (Concatenate)      (None, 49, 49, 128)  0           fire2/relu_expand1x1[0][0]
#                                                                  fire2/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# fire3/squeeze1x1 (Conv2D)       (None, 49, 49, 16)   2064        fire2/concat[0][0]
# __________________________________________________________________________________________________
# fire3/relu_squeeze1x1 (Activati (None, 49, 49, 16)   0           fire3/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire3/expand1x1 (Conv2D)        (None, 49, 49, 64)   1088        fire3/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire3/expand3x3 (Conv2D)        (None, 49, 49, 64)   9280        fire3/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire3/relu_expand1x1 (Activatio (None, 49, 49, 64)   0           fire3/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire3/relu_expand3x3 (Activatio (None, 49, 49, 64)   0           fire3/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire3/concat (Concatenate)      (None, 49, 49, 128)  0           fire3/relu_expand1x1[0][0]
#                                                                  fire3/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# pool3 (MaxPooling2D)            (None, 24, 24, 128)  0           fire3/concat[0][0]
# __________________________________________________________________________________________________
# fire4/squeeze1x1 (Conv2D)       (None, 24, 24, 32)   4128        pool3[0][0]
# __________________________________________________________________________________________________
# fire4/relu_squeeze1x1 (Activati (None, 24, 24, 32)   0           fire4/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire4/expand1x1 (Conv2D)        (None, 24, 24, 128)  4224        fire4/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire4/expand3x3 (Conv2D)        (None, 24, 24, 128)  36992       fire4/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire4/relu_expand1x1 (Activatio (None, 24, 24, 128)  0           fire4/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire4/relu_expand3x3 (Activatio (None, 24, 24, 128)  0           fire4/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire4/concat (Concatenate)      (None, 24, 24, 256)  0           fire4/relu_expand1x1[0][0]
#                                                                  fire4/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# fire5/squeeze1x1 (Conv2D)       (None, 24, 24, 32)   8224        fire4/concat[0][0]
# __________________________________________________________________________________________________
# fire5/relu_squeeze1x1 (Activati (None, 24, 24, 32)   0           fire5/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire5/expand1x1 (Conv2D)        (None, 24, 24, 128)  4224        fire5/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire5/expand3x3 (Conv2D)        (None, 24, 24, 128)  36992       fire5/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire5/relu_expand1x1 (Activatio (None, 24, 24, 128)  0           fire5/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire5/relu_expand3x3 (Activatio (None, 24, 24, 128)  0           fire5/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire5/concat (Concatenate)      (None, 24, 24, 256)  0           fire5/relu_expand1x1[0][0]
#                                                                  fire5/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# pool5 (MaxPooling2D)            (None, 11, 11, 256)  0           fire5/concat[0][0]
# __________________________________________________________________________________________________
# fire6/squeeze1x1 (Conv2D)       (None, 11, 11, 48)   12336       pool5[0][0]
# __________________________________________________________________________________________________
# fire6/relu_squeeze1x1 (Activati (None, 11, 11, 48)   0           fire6/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire6/expand1x1 (Conv2D)        (None, 11, 11, 192)  9408        fire6/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire6/expand3x3 (Conv2D)        (None, 11, 11, 192)  83136       fire6/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire6/relu_expand1x1 (Activatio (None, 11, 11, 192)  0           fire6/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire6/relu_expand3x3 (Activatio (None, 11, 11, 192)  0           fire6/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire6/concat (Concatenate)      (None, 11, 11, 384)  0           fire6/relu_expand1x1[0][0]
#                                                                  fire6/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# fire7/squeeze1x1 (Conv2D)       (None, 11, 11, 48)   18480       fire6/concat[0][0]
# __________________________________________________________________________________________________
# fire7/relu_squeeze1x1 (Activati (None, 11, 11, 48)   0           fire7/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire7/expand1x1 (Conv2D)        (None, 11, 11, 192)  9408        fire7/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire7/expand3x3 (Conv2D)        (None, 11, 11, 192)  83136       fire7/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire7/relu_expand1x1 (Activatio (None, 11, 11, 192)  0           fire7/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire7/relu_expand3x3 (Activatio (None, 11, 11, 192)  0           fire7/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire7/concat (Concatenate)      (None, 11, 11, 384)  0           fire7/relu_expand1x1[0][0]
#                                                                  fire7/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# fire8/squeeze1x1 (Conv2D)       (None, 11, 11, 64)   24640       fire7/concat[0][0]
# __________________________________________________________________________________________________
# fire8/relu_squeeze1x1 (Activati (None, 11, 11, 64)   0           fire8/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire8/expand1x1 (Conv2D)        (None, 11, 11, 256)  16640       fire8/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire8/expand3x3 (Conv2D)        (None, 11, 11, 256)  147712      fire8/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire8/relu_expand1x1 (Activatio (None, 11, 11, 256)  0           fire8/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire8/relu_expand3x3 (Activatio (None, 11, 11, 256)  0           fire8/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire8/concat (Concatenate)      (None, 11, 11, 512)  0           fire8/relu_expand1x1[0][0]
#                                                                  fire8/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# fire9/squeeze1x1 (Conv2D)       (None, 11, 11, 64)   32832       fire8/concat[0][0]
# __________________________________________________________________________________________________
# fire9/relu_squeeze1x1 (Activati (None, 11, 11, 64)   0           fire9/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire9/expand1x1 (Conv2D)        (None, 11, 11, 256)  16640       fire9/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire9/expand3x3 (Conv2D)        (None, 11, 11, 256)  147712      fire9/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire9/relu_expand1x1 (Activatio (None, 11, 11, 256)  0           fire9/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire9/relu_expand3x3 (Activatio (None, 11, 11, 256)  0           fire9/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire9/concat (Concatenate)      (None, 11, 11, 512)  0           fire9/relu_expand1x1[0][0]
#                                                                  fire9/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 512)          0           fire9/concat[0][0]
# ==================================================================================================
# Total params: 722,496
# Trainable params: 707,232
# Non-trainable params: 15,264
# __________________________________________________________________________________________________

# %% [markdown]
# Next, we will add dense layers and compile the `model`.
#
# - We do not need a `Flatten` layer, because we already incorporated a global average pooling layer when importing SqueezeNet.
#
# - The `Dropout` layer will help to prevent the model from overfitting to the training images.
#
# - The `relu` activations were chosen to help further combat vanishing gradients.
#
# - Finally, the `softmax` activation as this is a multi-class classification problem.

# %%
# Adding SqueezeNet to the model
model.add(pretrained)

# Adding additional dense layers
model.add(Dense(256))
model.add(Activation(relu))
model.add(Dropout(0.25))
model.add(Dense(512))
model.add(Activation(relu))

# Softmax as final activation function
model.add(Dense(classes, activation='softmax'))
    
# Istantiating Adam optimizer with a learning rate of 0.0001 and saving to variable 'optim'
optim = Adam(lr=0.0001)

# Compiling the CNN model 
model.compile(optimizer=optim, loss='categorical_crossentropy', metrics=['accuracy'])

# Display the model summary 
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# squeezenet (Model)           (None, 512)               722496
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# activation_1 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               131584
# _________________________________________________________________
# activation_2 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 29)                14877
# =================================================================
# Total params: 1,000,285
# Trainable params: 985,021
# Non-trainable params: 15,264
# _________________________________________________________________

# %%
# Saving the model summary as an image
plot_model(model, to_file='SqueezeNet_ASL.png', 
show_shapes=True, show_layer_names=True)

# %% [markdown]
# Image augmentation was configured using the following [resource](https://machinelearningmastery.com/how-to-configure-image-data-augmentation-when-training-deep-learning-neural-networks/).
#
# Images were augmented in the hopes of improving the model's ability to classify new ASL alphabet images (e.g., from a webcam capture in real-time).

# %%
# Istantiating the training/validation ImageDataGenerator()
datagen_train = ImageDataGenerator(rescale=1./255,
                                   horizontal_flip=True, 
                                   width_shift_range=[-5,5],
                                   zoom_range=0.1,
                                   shear_range=0.1,
                                   brightness_range=[0.9,1.2],
                                   fill_mode='reflect',
                                   validation_split=0.1)

# Istantiating the test generator
datagen_test = ImageDataGenerator(rescale=1./255,
                                   horizontal_flip=True, 
                                   width_shift_range=[-5,5],
                                   zoom_range=0.1,
                                   shear_range=0.1,
                                   brightness_range=[0.9,1.2],
                                   fill_mode='reflect')

# %%
# The generator for the training data, shuffle set to True 
# (unable to view confusion matrix and classification report as a result)
train_generator = datagen_train.flow_from_directory(path+'training_set/',
                                                    target_size=(pixels, pixels),
                                                    color_mode="rgb",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=True, subset='training')

# Generator for validation data, shuffle set to 'False' to allow for model evaluation
validation_generator = datagen_train.flow_from_directory(path+'training_set/',
                                                    target_size=(pixels, pixels),
                                                    color_mode="rgb",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=False, subset='validation')

# Generator for test data, shuffle set to 'False' to allow for model evaluation
test_generator = datagen_test.flow_from_directory(path+'test_set/',
                                                    target_size=(pixels, pixels),
                                                    color_mode="rgb",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=False)
# Out:
# Found 62640 images belonging to 29 classes.
# Found 6960 images belonging to 29 classes.
# Found 17400 images belonging to 29 classes.

# %%
# Saving the number of stepsizes for the training, validation and test sets 
train_stepsize = train_generator.n//train_generator.batch_size
valid_stepsize = validation_generator.samples//validation_generator.batch_size
test_stepsize = test_generator.samples//test_generator.batch_size

# Sanity check 
print(f'Training step size = {train_stepsize}, Validation step size = {valid_stepsize}')
print(f'Test step size = {test_stepsize}')
# Out:
# Training step size = 1566, Validation step size = 174
# Test step size = 435

# %% [markdown]
# Finally, we will utilize `keras.callbacks`:
#
# - `EarlyStopping()` to [prevent overfitting](https://machinelearningmastery.com/early-stopping-to-avoid-overtraining-neural-network-models/) to the training images, and
#
#
# - `ModelCheckpoint()` to [save the best model weights](https://machinelearningmastery.com/how-to-stop-training-deep-neural-networks-at-the-right-time-using-early-stopping/) based on loss achieved on the validation dataset, which may not coincide with the model at the end of training.

# %%
# Initiate early stop based on validation loss
# Will not stop before 'min_epochs' of 12 (patience)
ES = EarlyStopping(monitor='val_loss', mode='min', min_delta=0, patience=min_epochs, verbose=1)

# Model checkpointer that will only save the weights from the epoch with the best validation set loss
checkpoint = ModelCheckpoint("best_weights_squeeze.h5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')


# Adding both callbacks to a 'callbacks_list'
callbacks_list = [ES, checkpoint]

# %% [markdown]
# Now, we will train the model on the training ASL images.
#
# The model's progress will be saved to the variable `history` to allow for visualization of the progression of train and validation accuracies and losses.

# %%
# Fitting the model to the training data
history = model.fit_generator(generator=train_generator,
                                steps_per_epoch=train_stepsize,
                                epochs=epochs,
                                validation_data=validation_generator,
                                validation_steps=valid_stepsize,
                                callbacks=callbacks_list)
# Out:
# Epoch 1/30
# 1566/1566 [==============================] - 879s 562ms/step - loss: 0.6726 - accuracy: 0.7956 - val_loss: 0.0099 - val_accuracy: 0.9210
#
# Epoch 00001: val_loss improved from inf to 0.00990, saving model to best_weights_squeeze.h5
# Epoch 2/30
# 1566/1566 [==============================] - 646s 413ms/step - loss: 0.0807 - accuracy: 0.9735 - val_loss: 2.1512e-04 - val_accuracy: 0.9322
#
# Epoch 00002: val_loss improved from 0.00990 to 0.00022, saving model to best_weights_squeeze.h5
# Epoch 3/30
# 1566/1566 [==============================] - 649s 414ms/step - loss: 0.0448 - accuracy: 0.9853 - val_loss: 0.0036 - val_accuracy: 0.9226
#
# Epoch 00003: val_loss did not improve from 0.00022
# Epoch 4/30
# 1566/1566 [==============================] - 648s 414ms/step - loss: 0.0324 - accuracy: 0.9894 - val_loss: 2.9972e-05 - val_accuracy: 0.9451
#
# Epoch 00004: val_loss improved from 0.00022 to 0.00003, saving model to best_weights_squeeze.h5
# Epoch 5/30
# 1566/1566 [==============================] - 645s 412ms/step - loss: 0.0219 - accuracy: 0.9931 - val_loss: 1.4252e-04 - val_accuracy: 0.9596
#
# Epoch 00005: val_loss did not improve from 0.00003
# Epoch 6/30
# 1566/1566 [==============================] - 649s 415ms/step - loss: 0.0197 - accuracy: 0.9936 - val_loss: 1.1786e-05 - val_accuracy: 0.9586
#
# Epoch 00006: val_loss improved from 0.00003 to 0.00001, saving model to best_weights_squeeze.h5
# Epoch 7/30
# 1566/1566 [==============================] - 647s 413ms/step - loss: 0.0175 - accuracy: 0.9947 - val_loss: 1.1984e-04 - val_accuracy: 0.9681
#
# Epoch 00007: val_loss did not improve from 0.00001
# Epoch 8/30
# 1566/1566 [==============================] - 645s 412ms/step - loss: 0.0145 - accuracy: 0.9956 - val_loss: 0.0011 - val_accuracy: 0.9527
#
# Epoch 00008: val_loss did not improve from 0.00001
# Epoch 9/30
# 1566/1566 [==============================] - 650s 415ms/step - loss: 0.0130 - accuracy: 0.9958 - val_loss: 2.6822e-08 - val_accuracy: 0.9769
#
# Epoch 00009: val_loss improved from 0.00001 to 0.00000, saving model to best_weights_squeeze.h5
# Epoch 10/30
# 1566/1566 [==============================] - 648s 414ms/step - loss: 0.0118 - accuracy: 0.9966 - val_loss: 1.5768e-05 - val_accuracy: 0.9638
#
# Epoch 00010: val_loss did not improve from 0.00000
# Epoch 11/30
# 1566/1566 [==============================] - 646s 413ms/step - loss: 0.0102 - accuracy: 0.9968 - val_loss: 5.2296e-04 - val_accuracy: 0.9675
#
# Epoch 00011: val_loss did not improve from 0.00000
# Epoch 12/30
# 1566/1566 [==============================] - 649s 415ms/step - loss: 0.0089 - accuracy: 0.9973 - val_loss: 0.0031 - val_accuracy: 0.9588
#
# Epoch 00012: val_loss did not improve from 0.00000
# Epoch 13/30
# 1566/1566 [==============================] - 648s 414ms/step - loss: 0.0077 - accuracy: 0.9977 - val_loss: 3.9899e-05 - val_accuracy: 0.9651
#
# Epoch 00013: val_loss did not improve from 0.00000
# Epoch 14/30
# 1566/1566 [==============================] - 646s 413ms/step - loss: 0.0097 - accuracy: 0.9967 - val_loss: 1.1470e-04 - val_accuracy: 0.9716
#
# Epoch 00014: val_loss did not improve from 0.00000
# Epoch 15/30
# 1566/1566 [==============================] - 650s 415ms/step - loss: 0.0064 - accuracy: 0.9979 - val_loss: 7.6020e-05 - val_accuracy: 0.9789
#
# Epoch 00015: val_loss did not improve from 0.00000
# Epoch 16/30
# 1566/1566 [==============================] - 649s 414ms/step - loss: 0.0055 - accuracy: 0.9982 - val_loss: 1.9968e-07 - val_accuracy: 0.9813
#
# Epoch 00016: val_loss did not improve from 0.00000
# Epoch 17/30
# 1566/1566 [==============================] - 646s 413ms/step - loss: 0.0072 - accuracy: 0.9979 - val_loss: 0.0016 - val_accuracy: 0.9580
#
# Epoch 00017: val_loss did not improve from 0.00000
# Epoch 18/30
# 1566/1566 [==============================] - 650s 415ms/step - loss: 0.0049 - accuracy: 0.9986 - val_loss: 6.7651e-07 - val_accuracy: 0.9724
#
# Epoch 00018: val_loss did not improve from 0.00000
# Epoch 19/30
# 1566/1566 [==============================] - 647s 413ms/step - loss: 0.0069 - accuracy: 0.9981 - val_loss: 3.2783e-08 - val_accuracy: 0.9657
#
# Epoch 00019: val_loss did not improve from 0.00000
# Epoch 20/30
# 1566/1566 [==============================] - 646s 413ms/step - loss: 0.0051 - accuracy: 0.9986 - val_loss: 0.0031 - val_accuracy: 0.9545
#
# Epoch 00020: val_loss did not improve from 0.00000
# Epoch 21/30
# 1566/1566 [==============================] - 650s 415ms/step - loss: 0.0054 - accuracy: 0.9984 - val_loss: 0.0137 - val_accuracy: 0.9723
#
# Epoch 00021: val_loss did not improve from 0.00000
# Epoch 00021: early stopping

# %% [markdown]
# Visualizing the model's training and validation loss and accuracy progression for every epoch:

# %%
# Initializing the subplot 
plt.subplots(1,2,figsize=(20,10))

# Plotting the model's training and validation loss progression for every completed epoch 
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss', linewidth=2, marker='o', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2, marker='^', color='red')

# Formatting axes and titles
plt.suptitle('Optimizer : Adam , Learning Rate: 0.0001', fontsize=20)
plt.ylabel('Loss', fontsize=18)
plt.xlabel('Epoch', fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Formatting legend
plt.legend(loc='upper right', fontsize=18)

# Plotting the training and validation accuracy changes for every epoch 
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy', linewidth=2, marker='o', color='blue')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2, marker='^', color='red')

# Formatting axes and titles
plt.ylabel('Accuracy', fontsize=18)
plt.xlabel('Epoch', fontsize=18)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14)

# Formatting legend
plt.legend(loc='lower right', fontsize=18)

# Display the plots
plt.show()

# %% [markdown]
# ## Model Evaluation
#
# In order to evaluate the `bestmodel`'s performance we will need to load in the `best_weights_squeeze.h5` saved by `ModelCheckpoint()`.

# %%
# Saving the CNN architecture as a JSON
modelarch_json = model.to_json()
with open("squeeze_asl.json","w") as json_file:
    json_file.write(modelarch_json)
    
# Initialize the 'bestmodel' using the weights saved with the ModelCheckpoint callback
bestmodel = model_from_json(modelarch_json)

# Loading the weights that resulted in the best validation accuracy during training 
bestmodel.load_weights("best_weights_squeeze.h5")

# Compile the bestmodel
bestmodel.compile(optimizer=optim, loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# The `bestmodel` that resulted from training will be evaluated via classification reports and confusion matrices normalized by the number of images for the given class.

# %%
# Creating axis labels for future sns.heatmaps 

# Getting the class names
categories = list(train_generator.class_indices.keys())

# Preficing classes with 'Predicted ' 
predicted_labels = list('Predicted '  + category for category in categories)

# Preficing classes with 'True '
true_labels = list('True ' + category for category in categories)

# Creating labels(indices) for model evaluation metrics 
eval_metrics = list(bestmodel.metrics_names)

# %% [markdown]
# **NOTE:** Unable to create a classification report or confusion matrix for train data as train_generator(shuffle=True) does not save the shuffled order of the true classes.

# %%
# Re-evaluating the best model's performance on the training data
train_eval = bestmodel.evaluate_generator(train_generator, steps=train_stepsize)

# Saving the results to a dataframe
df_train_eval = pd.DataFrame(list(train_eval), index=eval_metrics, columns=['Train'])

# Display the results
print(df_train_eval)
# Out:
#              Train
# loss      0.000034
# accuracy  0.999393

# %% [markdown]
# Thus, `bestmodel` achieved <b>99.9% accuracy</b> and <b><i> < 0.0001</i></b> categorical crossentropy loss on the train dataset.
#
# -----
#
# ### Evaluating `bestmodel` Performance on the Validation Dataset
#
# First, we will acquire the model's predictions and save to variable `valid_predictions`.

# %%
# Getting bestmodel's predictions (as probabilities) on the validation images 
validation_probas = bestmodel.predict_generator(validation_generator, steps=valid_stepsize)

# Setting the model's class prediction as the class that received the highest probability for each image
valid_predictions = validation_probas.argmax(axis=1)

# Sanity check 
valid_predictions
# Out:
# array([ 0,  0,  0, ..., 28, 28, 28], dtype=int64)

# %% [markdown]
# Next, acquiring the images' true labels and saving to variable `valid_true`.

# %%
# Getting the true class labels for the validation data
valid_true = validation_generator.classes

# Sanity check 
valid_true
# Out:
# array([ 0,  0,  0, ..., 28, 28, 28])

# %% [markdown]
# Finally, we will compare `valid_predictions` with `valid_true` to acquire model accuracy, precision, recall, f1-scores and a confusion matrix.

# %%
# Evaluating bestmodel's performance on the validation data 
valid_eval = bestmodel.evaluate_generator(validation_generator, steps=valid_stepsize)

# Saving the results to a dataframe
df_valid_eval = pd.DataFrame(list(valid_eval), index=eval_metrics, columns=['Validation'])

# Display the results 
print(df_valid_eval)
# Out:
#           Validation
# loss        0.000001
# accuracy    0.977730

# %% [markdown]
# Thus, `bestmodel` achieved <b>97.8% accuracy</b> and <b><i> < 0.00001</i></b> categorical crossentropy loss on the validation dataset.

# %%
# Displaying the classification report for the validation set
print('Validation Classification Report\n \n', classification_report(valid_true, valid_predictions, target_names=categories))
# Out:
# Validation Classification Report
#
#                precision    recall  f1-score   support
#
#            A       0.98      1.00      0.99       240
#            B       1.00      1.00      1.00       240
#            C       1.00      1.00      1.00       240
#            D       1.00      1.00      1.00       240
#            E       0.98      1.00      0.99       240
#            F       0.99      1.00      1.00       240
#            G       0.94      0.99      0.96       240
#            H       1.00      0.93      0.97       240
#            I       1.00      0.98      0.99       240
#            J       0.98      1.00      0.99       240
#            K       1.00      0.99      0.99       240
#            L       1.00      1.00      1.00       240
#            M       0.94      0.97      0.95       240
#            N       0.98      0.91      0.94       240
#            O       1.00      0.95      0.98       240
#            P       0.96      1.00      0.98       240
#            Q       0.97      1.00      0.98       240
#            R       0.96      1.00      0.98       240
#            S       0.88      0.96      0.92       240
#            T       0.95      0.97      0.96       240
#            U       0.98      0.96      0.97       240
#            V       0.99      0.96      0.97       240
#            W       0.95      1.00      0.97       240
#            X       1.00      0.87      0.93       240
#            Y       0.95      0.99      0.97       240
#            Z       0.99      0.98      0.99       240
#          del       1.00      0.97      0.98       240
#      nothing       1.00      0.95      0.97       240
#        space       1.00      1.00      1.00       240
#
#     accuracy                           0.98      6960
#    macro avg       0.98      0.98      0.98      6960
# weighted avg       0.98      0.98      0.98      6960

# %% [markdown]
# The model achieved high precision, recall and f1-scores, which ranged from <b>87 - 100 %</b> with most scores in the mid to high 90s when predicting on the validation set.
#
# The metrics in the classifcation report aligned with `bestmodel`'s accuracy score, which can be expected given the balanced number of images in each class.

# %%
# Creating a non-normalized confusion matrix for the validation set
valid_matrix = pd.DataFrame(confusion_matrix(valid_true, valid_predictions), columns=predicted_labels, index=true_labels)

# Display the matrix
valid_matrix
# Out:
#               Predicted A  Predicted B  Predicted C  Predicted D  Predicted E  \
# True A                240            0            0            0            0
# True B                  0          240            0            0            0
# True C                  0            0          240            0            0
# True D                  0            0            0          240            0
# True E                  0            0            0            0          240
# True F                  0            0            0            0            0
# True G                  0            0            0            0            0
# True H                  0            0            0            0            0
# True I                  0            0            0            0            4
# True J                  0            0            0            0            0
# True K                  0            0            0            0            0
# True L                  0            0            0            0            0
# True M                  0            0            0            0            0
# True N                  0            0            0            0            0
# True O                  0            0            0            0            0
# True P                  0            0            0            0            0
# True Q                  0            0            0            0            0
# True R                  0            0            0            0            0
# True S                  0            0            0            0            0
# True T                  6            0            0            0            0
# True U                  0            1            0            0            0
# True V                  0            0            0            0            0
# True W                  0            0            0            0            0
# True X                  0            0            0            0            0
# True Y                  0            0            0            0            0
# True Z                  0            0            0            0            0
# True del                0            0            0            0            0
# True nothing            0            0            0            0            0
# True space              0            0            0            0            0
#
#               Predicted F  Predicted G  Predicted H  Predicted I  Predicted J  \
# True A                  0            0            0            0            0
# True B                  0            0            0            0            0
# True C                  0            0            0            0            0
# True D                  0            0            0            0            0
# True E                  0            0            0            0            0
# True F                240            0            0            0            0
# True G                  0          238            0            0            0
# True H                  0           16          224            0            0
# True I                  0            0            0          235            0
# True J                  0            0            0            0          240
# True K                  0            0            0            0            0
# True L                  0            0            0            0            0
# True M                  0            0            0            0            0
# True N                  1            0            0            0            0
# True O                  1            0            0            0            0
# True P                  0            0            0            0            0
# True Q                  0            0            0            0            0
# True R                  0            0            0            0            0
# True S                  0            0            0            0            1
# True T                  0            0            0            0            0
# True U                  0            0            0            0            0
# True V                  0            0            0            0            0
# True W                  0            0            0            0            0
# True X                  0            0            0            0            3
# True Y                  0            0            0            0            0
# True Z                  0            0            0            0            0
# True del                0            0            0            0            0
# True nothing            0            0            0            0            0
# True space              0            0            0            0            0
#
#               ...  Predicted T  Predicted U  Predicted V  Predicted W  \
# True A        ...            0            0            0            0
# True B        ...            0            0            0            0
# True C        ...            0            0            0            0
# True D        ...            0            0            0            0
# True E        ...            0            0            0            0
# True F        ...            0            0            0            0
# True G        ...            0            0            0            0
# True H        ...            0            0            0            0
# True I        ...            0            0            0            0
# True J        ...            0            0            0            0
# True K        ...            0            0            0            0
# True L        ...            0            0            0            0
# True M        ...            0            0            0            2
# True N        ...            1            0            0            2
# True O        ...           10            0            0            0
# True P        ...            0            0            0            0
# True Q        ...            0            0            0            0
# True R        ...            0            0            0            0
# True S        ...            0            0            0            0
# True T        ...          232            0            0            0
# True U        ...            0          231            1            0
# True V        ...            0            5          230            4
# True W        ...            0            0            1          239
# True X        ...            0            0            0            0
# True Y        ...            2            0            0            0
# True Z        ...            0            0            0            0
# True del      ...            0            0            0            0
# True nothing  ...            0            0            0            5
# True space    ...            0            0            0            0
#
#               Predicted X  Predicted Y  Predicted Z  Predicted del  \
# True A                  0            0            0              0
# True B                  0            0            0              0
# True C                  0            0            0              0
# True D                  0            0            0              0
# True E                  0            0            0              0
# True F                  0            0            0              0
# True G                  0            0            0              0
# True H                  0            0            0              0
# True I                  0            0            0              0
# True J                  0            0            0              0
# True K                  0            0            0              0
# True L                  0            0            0              0
# True M                  0            0            0              0
# True N                  0            0            0              0
# True O                  0            0            0              0
# True P                  0            0            0              0
# True Q                  0            0            0              0
# True R                  0            0            0              0
# True S                  1            0            1              0
# True T                  0            1            1              0
# True U                  0            0            0              0
# True V                  0            0            0              0
# True W                  0            0            0              0
# True X                208            0            0              0
# True Y                  0          238            0              0
# True Z                  0            4          236              0
# True del                0            0            0            232
# True nothing            0            8            0              0
# True space              0            0            0              0
#
#               Predicted nothing  Predicted space
# True A                        0                0
# True B                        0                0
# True C                        0                0
# True D                        0                0
# True E                        0                0
# True F                        0                0
# True G                        0                0
# True H                        0                0
# True I                        0                0
# True J                        0                0
# True K                        0                0
# True L                        0                0
# True M                        0                0
# True N                        1                0
# True O                        0                0
# True P                        0                0
# True Q                        0                0
# True R                        0                0
# True S                        0                0
# True T                        0                0
# True U                        0                0
# True V                        0                0
# True W                        0                0
# True X                        0                0
# True Y                        0                0
# True Z                        0                0
# True del                      0                0
# True nothing                227                0
# True space                    0              240
#
# [29 rows x 29 columns]

# %%
# Plotting the normalized confusion matrix (proportion of predictions by class) as a heatmap

# Increasing fontsize
sns.set(font_scale=1.2)

# Creating the plot
plt.figure(figsize=(15,15))
sns.heatmap(round(valid_matrix/valid_matrix.sum(axis=1)[:,np.newaxis],2), cmap='Blues', annot=True, linewidths=.5, linecolor='black')

# Formatting the title 
plt.title('Normalized Confusion Matrix: Validation Data', fontsize=20)

# Display the normalized confusion matrix
plt.show()

# %% [markdown]
# Based on the non-normalized and normalized confusion matrices, `bestmodel` proved successful at predicting the classes of the validation set.
#
# -----
#
# ### Evaluating `bestmodel` Performance on the Test Dataset
#
# Similar as above, we will first acquire the model's predictions and saving to variable `test_predictions`.

# %%
# Getting bestmodel's predictions (as probabilities) on the test set 
test_probas = bestmodel.predict_generator(test_generator, steps=test_stepsize)

# Setting the model's class prediction as the class that received the highest probability for each image
test_predictions = test_probas.argmax(axis=1)

# Sanity check 
test_predictions
# Out:
# array([ 0,  0,  0, ..., 28, 28, 28], dtype=int64)

# %% [markdown]
# Next, saving the true classes of the test images to the variable `test_true`.

# %%
# Getting the true class labels for the test set
test_true = test_generator.classes

# Sanity check 
test_true
# Out:
# array([ 0,  0,  0, ..., 28, 28, 28])

# %% [markdown]
# Finally, we will compare `test_predictions` with `test_true` to acquire model accuracy, precision, recall, f1-scores and confusion matrices to evaluate model performance on the test set.

# %%
# Evaluating the best model's performance on the test data 
test_eval = bestmodel.evaluate_generator(test_generator, steps=test_stepsize)

# Saving the results to a dataframe 
df_test_eval = pd.DataFrame(list(test_eval), index=eval_metrics, columns=['Test'])

# Display the results
print(df_test_eval)
# Out:
#               Test
# loss      0.000000
# accuracy  0.996609

# %% [markdown]
# `bestmodel` achieved <b>99.7% accuracy</b> and <b><i>< 0.00001</i></b> categorical crossentropy loss on the test set.

# %%
# Displaying the classification report for the test set
print('Test Classification Report\n \n', classification_report(test_true, test_predictions, target_names=categories))
# Out:
# Test Classification Report
#
#                precision    recall  f1-score   support
#
#            A       1.00      1.00      1.00       600
#            B       1.00      1.00      1.00       600
#            C       1.00      1.00      1.00       600
#            D       1.00      1.00      1.00       600
#            E       1.00      1.00      1.00       600
#            F       1.00      1.00      1.00       600
#            G       0.99      1.00      1.00       600
#            H       1.00      0.99      1.00       600
#            I       1.00      1.00      1.00       600
#            J       1.00      1.00      1.00       600
#            K       1.00      1.00      1.00       600
#            L       1.00      1.00      1.00       600
#            M       1.00      1.00      1.00       600
#            N       1.00      0.99      1.00       600
#            O       1.00      0.99      1.00       600
#            P       1.00      1.00      1.00       600
#            Q       0.99      1.00      1.00       600
#            R       0.99      1.00      1.00       600
#            S       0.98      0.99      0.99       600
#            T       0.99      0.99      0.99       600
#            U       0.99      0.99      0.99       600
#            V       1.00      0.99      0.99       600
#            W       1.00      1.00      1.00       600
#            X       1.00      0.98      0.99       600
#            Y       1.00      1.00      1.00       600
#            Z       1.00      1.00      1.00       600
#          del       1.00      0.99      1.00       600
#      nothing       1.00      1.00      1.00       600
#        space       1.00      1.00      1.00       600
#
#     accuracy                           1.00     17400
#    macro avg       1.00      1.00      1.00     17400
# weighted avg       1.00      1.00      1.00     17400

# %% [markdown]
# `bestmodel` also achieved great precision, recall and f1-scores, which ranged from <b>98 - 100 %</b>.

# %%
# Non-normalized confusion matrix for the test data
test_matrix = pd.DataFrame(confusion_matrix(test_true, test_predictions), columns=predicted_labels, index=true_labels)

# Plotting a normalized confusion matrix for the test data as a heatmap 
sns.set(font_scale=1.2)
plt.figure(figsize=(15,15))
sns.heatmap(round(test_matrix/test_matrix.sum(axis=1)[:,np.newaxis],2), cmap='Blues', annot=True, linewidths=.5, linecolor='black')
plt.title('Normalized Confusion Matrix: Test Data', fontsize=20)
plt.show()

# %% [markdown]
# Based on the non-normalized and normalized confusion matrices, the SqueeezNet model trained on ASL alphabet images was able to successfully predict the classes of images it had never seen before (i.e., test set images).
#
# However, the test images were very similar to the images that the SqueezeNet CNN was trained on, which may account for the strong model performance seen on both the validation and test sets.
#
# -----
#
# Keeping in mind that the final goal is to classify letters of the ASL alphabet from new images taken in real-time, the `best_weights_squeeze.h5` obtained from the training of SqueezeNet in this notebook will undergo additional evaluation of:
#
# **Predicting on images taken from live webcam in the subsequent notebook** `real-time_test.ipynb`.
