# %% [markdown]
# # Training `Xception` to Classify ASL Letters
#
# In this notebook we will be training a `keras.applications.Xception` Convolutional Neural Network (CNN) on the [ASL alphabet images](https://www.kaggle.com/grassknoted/asl-alphabet) preprocessed and organized using [<b><i>split_only_asl.sh</i></b>](https://github.com/angelphanth/alphabet_asl/blob/master/data_augmentation/split_only_asl.sh) and [<b><i>bright_images.py</i></b>](https://github.com/angelphanth/alphabet_asl/blob/master/data_augmentation/bright_images.py).
#
# **Model Evaluation**
#
# Xception model performance when classifying the existing test images will then be evaluated using `sklearn.metrics.classification_report` and `confusion_matrix`.
#
# Model performance on real-time images will similarly be evaluated in: <b><i>real-time_test.py</i></b>.

# %%
# Importing the usual libraries 
import pandas as pd
import numpy as np

# Importing Xception
from keras.applications.xception import Xception

# Model Configuration 
from keras.layers import Dense, Dropout, Activation
from keras.activations import relu
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Model, model_from_json, Sequential
from keras.optimizers import Adam
from keras.utils import plot_model

# Model Evaluation
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Why Xception?
# Introduced by [François Chollet](https://arxiv.org/abs/1610.02357), who is also the author of the Keras library, Xception is an adaptation of the Inception networks.
#
# >**What is Inception?**
# >Inception NNs sought to improve image classification performance while having more efficient computations by going [wider rather than deeper in terms of their architecture](https://towardsdatascience.com/an-intuitive-guide-to-deep-network-architectures-65fdc477db41). Fundamental to the Inception networks are their **Inception modules**, which consist of covolutions with different kernel sizes occurring in parallel (width-wise rather than depth-wise). Visualizations of the different Inception CNNs and a more in-depth explanation can be found [here](https://towardsdatascience.com/illustrated-10-cnn-architectures-95d78ace614d#c5a6).
#
# Instead of the Inception modules, Xception replaces them with [depth-wise separable convolutions](https://medium.com/@zurister/depth-wise-convolution-and-depth-wise-separable-convolution-37346565d4ec).
#
# As demonstrated in [Chollet's paper](https://arxiv.org/abs/1610.02357), when compared to InceptionV3, Xception performs slightly better when classifying the ImageNet dataset (1,000 classes) and performs immensely better on Google's even larger JFT dataset (17,000 classes). The differences in performance despite having a similar number of parameters suggests that Xception is also more [computationally efficient](https://towardsdatascience.com/an-intuitive-guide-to-deep-network-architectures-65fdc477db41).
#
# Also, unlike classic CNN frameworks, like VGG16 and VGG19, Xception also incorporates [**residual or "skip" or "shortcut" connections**](https://towardsdatascience.com/an-intuitive-guide-to-deep-network-architectures-65fdc477db41) that offer a shortcut for gradient signals to get to earlier layers during backpropagation, which helps to combat the problem of vanishing gradients. The addition of residual connections result in faster convergence and classification performance (when compared to a varient of Xception without residual connections).
#
#
# -------
#
# Transfer learning was configured using the following Medium articles written by [Parkash Jay](https://medium.com/@14prakash/transfer-learning-using-keras-d804b2e04ef8) and [James Le](https://towardsdatascience.com/the-4-convolutional-neural-network-models-that-can-classify-your-fashion-images-9fe7f3e5399d).
#
# Xception will be trained on 80% of the ASL alphabet images. To review, the dataset of square (200 `pixels` by 200 pixels), colour (3 `channels`) images contains 29 `classes`.
#
# The images will be fed into the `model` in `batch_size`s of 40. An iterative process, each batch is considered a bout of learning where given the model's performance on that batch its trainable parameters will be tweaked in an attempt to minimize the amount of error (or `categorical_crossentropy`) on the next batch of images.
#
# Once the model has seen all the images in the dataset via **X** number of batches/`steps` then the model has completed one **epoch**. The model will undergo a minimum of `12` and a maximum of `30` epochs.

# %%
# Saving variables that will be called upon throughout the notebook 
classes = 29 
pixels = 200
channels = 3 
path = '../brighten_only/'
batch_size = 40

# Training the model for a minimum of 12 and maximum of 30 epochs
min_epochs=12
epochs=30

# Initialize the model 
model = Sequential()

# %%
# Import Xception architecture with weights trained on 'imagenet', do not include the top layers
pretrained = Xception(weights='imagenet', include_top=False, pooling='avg', input_shape=(pixels,pixels,channels))

# Total layers
total_layers = len(pretrained.layers)

# 20% of layers
no_train_layers = int(total_layers *0.2)

# Sanity check 
print(f'The first {no_train_layers} will not be trainable.')
# Out:
# The first 26 will not be trainable.

# %%
# Setting the first few layers to NOT trainable so weights won't be tweaked
for layer in pretrained.layers[:no_train_layers]:
    layer.trainable=False
    
# Allow all other layers to be trained on the ASL images    
for layer in pretrained.layers[no_train_layers:]:
    layer.trainable=True
    
# Display Xception architecture
pretrained.summary()
# Out:
# Model: "xception"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 200, 200, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 99, 99, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 99, 99, 32)   128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 99, 99, 32)   0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 97, 97, 64)   18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 97, 97, 64)   256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 97, 97, 64)   0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 97, 97, 128)  8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 97, 97, 128)  512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 97, 97, 128)  0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 97, 97, 128)  17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 97, 97, 128)  512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 49, 49, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 49, 49, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 49, 49, 128)  512         conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 49, 49, 128)  0           block2_pool[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 49, 49, 128)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 49, 49, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 49, 49, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 49, 49, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 49, 49, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 49, 49, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 25, 25, 256)  32768       add_1[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 25, 25, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 25, 25, 256)  1024        conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 25, 25, 256)  0           block3_pool[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 25, 25, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 25, 25, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 25, 25, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 25, 25, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 25, 25, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 25, 25, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 13, 13, 728)  186368      add_2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 13, 13, 728)  0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 13, 13, 728)  2912        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 13, 13, 728)  0           block4_pool[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 13, 13, 728)  0           add_3[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 13, 13, 728)  536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 13, 13, 728)  2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 13, 13, 728)  0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 13, 13, 728)  536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 13, 13, 728)  2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 13, 13, 728)  0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 13, 13, 728)  536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 13, 13, 728)  2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 13, 13, 728)  0           block5_sepconv3_bn[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 13, 13, 728)  0           add_4[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 13, 13, 728)  536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 13, 13, 728)  2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 13, 13, 728)  0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 13, 13, 728)  536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 13, 13, 728)  2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 13, 13, 728)  0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 13, 13, 728)  536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 13, 13, 728)  2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 13, 13, 728)  0           block6_sepconv3_bn[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 13, 13, 728)  0           add_5[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 13, 13, 728)  536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 13, 13, 728)  2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 13, 13, 728)  0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 13, 13, 728)  536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 13, 13, 728)  2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 13, 13, 728)  0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 13, 13, 728)  536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 13, 13, 728)  2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 13, 13, 728)  0           block7_sepconv3_bn[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 13, 13, 728)  0           add_6[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 13, 13, 728)  536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 13, 13, 728)  2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 13, 13, 728)  0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 13, 13, 728)  536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 13, 13, 728)  2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 13, 13, 728)  0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 13, 13, 728)  536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 13, 13, 728)  2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 13, 13, 728)  0           block8_sepconv3_bn[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 13, 13, 728)  0           add_7[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 13, 13, 728)  536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 13, 13, 728)  2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 13, 13, 728)  0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 13, 13, 728)  536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 13, 13, 728)  2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 13, 13, 728)  0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 13, 13, 728)  536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 13, 13, 728)  2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 13, 13, 728)  0           block9_sepconv3_bn[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 13, 13, 728)  0           add_8[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 13, 13, 728)  536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 13, 13, 728)  2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 13, 13, 728)  0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 13, 13, 728)  536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 13, 13, 728)  2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 13, 13, 728)  0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 13, 13, 728)  536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 13, 13, 728)  2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 13, 13, 728)  0           block10_sepconv3_bn[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 13, 13, 728)  0           add_9[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 13, 13, 728)  536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 13, 13, 728)  2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 13, 13, 728)  0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 13, 13, 728)  536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 13, 13, 728)  2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 13, 13, 728)  0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 13, 13, 728)  536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 13, 13, 728)  2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 13, 13, 728)  0           block11_sepconv3_bn[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 13, 13, 728)  0           add_10[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 13, 13, 728)  536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 13, 13, 728)  2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 13, 13, 728)  0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 13, 13, 728)  536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 13, 13, 728)  2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 13, 13, 728)  0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 13, 13, 728)  536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 13, 13, 728)  2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 13, 13, 728)  0           block12_sepconv3_bn[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 13, 13, 728)  0           add_11[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 13, 13, 728)  536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 13, 13, 728)  2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 13, 13, 728)  0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 13, 13, 1024) 752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 13, 13, 1024) 4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 7, 7, 1024)   745472      add_11[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 7, 7, 1024)   0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 7, 7, 1024)   4096        conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 7, 7, 1024)   0           block13_pool[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 7, 7, 1536)   1582080     add_12[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 7, 7, 1536)   6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 7, 7, 1536)   0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 7, 7, 2048)   3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 7, 7, 2048)   8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 7, 7, 2048)   0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 2048)         0           block14_sepconv2_act[0][0]
# ==================================================================================================
# Total params: 20,861,480
# Trainable params: 20,616,136
# Non-trainable params: 245,344
# __________________________________________________________________________________________________

# %% [markdown]
# Next, we will add dense layers and compile the `model`.

# %%
# Adding Xception to the model
model.add(pretrained)

# Adding additional dense layers
model.add(Dense(256))
model.add(Activation(relu))
model.add(Dropout(0.25))
model.add(Dense(512))
model.add(Activation(relu))

# Softmax as final activation function
model.add(Dense(classes, activation='softmax'))
    
# Istantiating Adam optimizer with a learning rate of 0.0001 and saving to variable 'optim'
optim = Adam(lr=0.0001)

# Compiling the CNN model 
model.compile(optimizer=optim, loss='categorical_crossentropy', metrics=['accuracy'])

# Display the model summary 
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# xception (Model)             (None, 2048)              20861480
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               524544
# _________________________________________________________________
# activation_1 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               131584
# _________________________________________________________________
# activation_2 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 29)                14877
# =================================================================
# Total params: 21,532,485
# Trainable params: 21,287,141
# Non-trainable params: 245,344
# _________________________________________________________________

# %%
# Saving the model summary as an image
plot_model(model, to_file='Xception_ASL.png', 
show_shapes=True, show_layer_names=True)

# %% [markdown]
# Image augmentation was configured using the following [resource](https://machinelearningmastery.com/how-to-configure-image-data-augmentation-when-training-deep-learning-neural-networks/).
#
# Images were augmented in the hopes of improving the model's ability to classify new ASL alphabet images (e.g., real-time webcam images).

# %%
# Istantiating the training/validation ImageDataGenerator()
datagen_train = ImageDataGenerator(rescale=1./255,
                                   horizontal_flip=True, 
                                   width_shift_range=[-5,5],
                                   zoom_range=0.1,
                                   shear_range=0.1,
                                   brightness_range=[0.9,1.2],
                                   fill_mode='reflect',
                                   validation_split=0.1)

# Istantiating the test generator
datagen_test = ImageDataGenerator(rescale=1./255,
                                   horizontal_flip=True, 
                                   width_shift_range=[-5,5],
                                   zoom_range=0.1,
                                   shear_range=0.1,
                                   brightness_range=[0.9,1.2],
                                   fill_mode='reflect')

# %%
# The generator for the training data, shuffle set to True 
# (unable to view confusion matrix and classification report as a result)
train_generator = datagen_train.flow_from_directory(path+'training_set/',
                                                    target_size=(pixels, pixels),
                                                    color_mode="rgb",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=True, subset='training')

# Generator for validation data, shuffle set to 'False' to allow for model evaluation
validation_generator = datagen_train.flow_from_directory(path+'training_set/',
                                                    target_size=(pixels, pixels),
                                                    color_mode="rgb",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=False, subset='validation')

# Generator for test data, shuffle set to 'False' to allow for model evaluation
test_generator = datagen_test.flow_from_directory(path+'test_set/',
                                                    target_size=(pixels, pixels),
                                                    color_mode="rgb",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=False)
# Out:
# Found 62640 images belonging to 29 classes.
# Found 6960 images belonging to 29 classes.
# Found 17400 images belonging to 29 classes.

# %%
# Saving the number of stepsizes for the training, validation and test sets 
train_stepsize = train_generator.n//train_generator.batch_size
valid_stepsize = validation_generator.samples//validation_generator.batch_size
test_stepsize = test_generator.samples//test_generator.batch_size

# Sanity check 
print(f'Training step size = {train_stepsize}, Validation step size = {valid_stepsize}')
print(f'Test step size = {test_stepsize}')
# Out:
# Training step size = 1566, Validation step size = 174
# Test step size = 435

# %% [markdown]
# Finally, we will utilize `keras.callbacks`:
#
# - `EarlyStopping()` to [prevent overfitting](https://machinelearningmastery.com/early-stopping-to-avoid-overtraining-neural-network-models/) to the training images, and
#
#
# - `ModelCheckpoint()` to [save the best model weights](https://machinelearningmastery.com/how-to-stop-training-deep-neural-networks-at-the-right-time-using-early-stopping/) based on accuracy scores achieved on the validation dataset, which may not coincide with the model at the end of training.

# %%
# Early stopping will help prevent overfitting the model to the train data, 
# Initiate early stop based on validation accuracy
# Will not stop before 'min_epochs' of 12 (patience)
ES = EarlyStopping(monitor='val_loss', mode='min', min_delta=0, patience=min_epochs, verbose=1)

# Model checkpointer that will only save the weights from the epoch with the best validation set accuracy
checkpoint = ModelCheckpoint("best_weights_xception.h5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')


# Adding both callbacks to a 'callbacks_list'
callbacks_list = [ES, checkpoint]

# %% [markdown]
# Now, we will train the model on the training ASL images.
#
# The model's progress will be saved to the variable `history` to allow for visualization of the progression of train and validation accuracies and losses.

# %%
# Fitting the model to the training data
history = model.fit_generator(generator=train_generator,
                                steps_per_epoch=train_stepsize,
                                epochs=epochs,
                                validation_data=validation_generator,
                                validation_steps=valid_stepsize,
                                callbacks=callbacks_list)
# Out:
# Epoch 1/30
# 1566/1566 [==============================] - 1206s 770ms/step - loss: 0.1663 - accuracy: 0.9635 - val_loss: 6.0448e-05 - val_accuracy: 0.9226
#
# Epoch 00001: val_loss improved from inf to 0.00006, saving model to best_weights_xception.h5
# Epoch 2/30
# 1566/1566 [==============================] - 1193s 762ms/step - loss: 0.0115 - accuracy: 0.9970 - val_loss: 4.7041e-04 - val_accuracy: 0.9634
#
# Epoch 00002: val_loss did not improve from 0.00006
# Epoch 3/30
# 1566/1566 [==============================] - 1193s 762ms/step - loss: 0.0065 - accuracy: 0.9986 - val_loss: 9.5171e-04 - val_accuracy: 0.9733
#
# Epoch 00003: val_loss did not improve from 0.00006
# Epoch 4/30
# 1566/1566 [==============================] - 1193s 762ms/step - loss: 0.0095 - accuracy: 0.9977 - val_loss: 4.0548e-04 - val_accuracy: 0.9668
#
# Epoch 00004: val_loss did not improve from 0.00006
# Epoch 5/30
# 1566/1566 [==============================] - 1194s 762ms/step - loss: 0.0051 - accuracy: 0.9987 - val_loss: 8.7619e-07 - val_accuracy: 0.9805
#
# Epoch 00005: val_loss improved from 0.00006 to 0.00000, saving model to best_weights_xception.h5
# Epoch 6/30
# 1566/1566 [==============================] - 1195s 763ms/step - loss: 0.0059 - accuracy: 0.9987 - val_loss: 9.1194e-07 - val_accuracy: 0.9760
#
# Epoch 00006: val_loss did not improve from 0.00000
# Epoch 7/30
# 1566/1566 [==============================] - 1193s 762ms/step - loss: 0.0051 - accuracy: 0.9988 - val_loss: 0.2245 - val_accuracy: 0.9638
#
# Epoch 00007: val_loss did not improve from 0.00000
# Epoch 8/30
# 1566/1566 [==============================] - 1138s 727ms/step - loss: 0.0047 - accuracy: 0.9988 - val_loss: 0.1769 - val_accuracy: 0.9661
#
# Epoch 00008: val_loss did not improve from 0.00000
# Epoch 9/30
# 1566/1566 [==============================] - 1193s 762ms/step - loss: 0.0052 - accuracy: 0.9990 - val_loss: 5.6810e-04 - val_accuracy: 0.9760
#
# Epoch 00009: val_loss did not improve from 0.00000
# Epoch 10/30
# 1566/1566 [==============================] - 1194s 762ms/step - loss: 0.0056 - accuracy: 0.9989 - val_loss: 7.3410e-05 - val_accuracy: 0.9731
#
# Epoch 00010: val_loss did not improve from 0.00000
# Epoch 11/30
# 1566/1566 [==============================] - 1194s 763ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 1.1612e-05 - val_accuracy: 0.9609
#
# Epoch 00011: val_loss did not improve from 0.00000
# Epoch 12/30
# 1566/1566 [==============================] - 1197s 764ms/step - loss: 0.0044 - accuracy: 0.9992 - val_loss: 5.2672e-05 - val_accuracy: 0.9743
#
# Epoch 00012: val_loss did not improve from 0.00000
# Epoch 13/30
# 1566/1566 [==============================] - 1198s 765ms/step - loss: 0.0036 - accuracy: 0.9994 - val_loss: 0.0026 - val_accuracy: 0.9812
#
# Epoch 00013: val_loss did not improve from 0.00000
# Epoch 14/30
# 1566/1566 [==============================] - 1196s 763ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 8.4696e-06 - val_accuracy: 0.9747
#
# Epoch 00014: val_loss did not improve from 0.00000
# Epoch 15/30
# 1566/1566 [==============================] - 1196s 764ms/step - loss: 0.0065 - accuracy: 0.9988 - val_loss: 1.0785e-05 - val_accuracy: 0.9536
#
# Epoch 00015: val_loss did not improve from 0.00000
# Epoch 16/30
# 1566/1566 [==============================] - 1191s 761ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 6.2585e-08 - val_accuracy: 0.9749
#
# Epoch 00016: val_loss improved from 0.00000 to 0.00000, saving model to best_weights_xception.h5
# Epoch 17/30
# 1566/1566 [==============================] - 1191s 761ms/step - loss: 0.0056 - accuracy: 0.9990 - val_loss: 5.2769e-05 - val_accuracy: 0.9316
#
# Epoch 00017: val_loss did not improve from 0.00000
# Epoch 18/30
# 1566/1566 [==============================] - 1195s 763ms/step - loss: 0.0026 - accuracy: 0.9995 - val_loss: 4.1424e-06 - val_accuracy: 0.9769
#
# Epoch 00018: val_loss did not improve from 0.00000
# Epoch 19/30
# 1566/1566 [==============================] - 1145s 731ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 8.2242e-04 - val_accuracy: 0.9562
#
# Epoch 00019: val_loss did not improve from 0.00000
# Epoch 20/30
# 1566/1566 [==============================] - 1187s 758ms/step - loss: 0.0040 - accuracy: 0.9992 - val_loss: 9.2088e-07 - val_accuracy: 0.9529
#
# Epoch 00020: val_loss did not improve from 0.00000
# Epoch 21/30
# 1566/1566 [==============================] - 1191s 761ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 8.9407e-09 - val_accuracy: 0.9543
#
# Epoch 00021: val_loss improved from 0.00000 to 0.00000, saving model to best_weights_xception.h5
# Epoch 22/30
# 1566/1566 [==============================] - 1166s 744ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 2.1116e-05 - val_accuracy: 0.9585
#
# Epoch 00022: val_loss did not improve from 0.00000
# Epoch 23/30
# 1566/1566 [==============================] - 1166s 744ms/step - loss: 0.0058 - accuracy: 0.9990 - val_loss: 1.3202e-06 - val_accuracy: 0.9540
#
# Epoch 00023: val_loss did not improve from 0.00000
# Epoch 24/30
# 1566/1566 [==============================] - 1195s 763ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 1.3530e-06 - val_accuracy: 0.9652
#
# Epoch 00024: val_loss did not improve from 0.00000
# Epoch 25/30
# 1566/1566 [==============================] - 1191s 761ms/step - loss: 0.0044 - accuracy: 0.9994 - val_loss: 7.1375e-06 - val_accuracy: 0.9540
#
# Epoch 00025: val_loss did not improve from 0.00000
# Epoch 26/30
# 1566/1566 [==============================] - 1136s 725ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 1.6868e-06 - val_accuracy: 0.9655
#
# Epoch 00026: val_loss did not improve from 0.00000
# Epoch 27/30
# 1566/1566 [==============================] - 1191s 761ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 2.0862e-08 - val_accuracy: 0.9591
#
# Epoch 00027: val_loss did not improve from 0.00000
# Epoch 28/30
# 1566/1566 [==============================] - 1191s 761ms/step - loss: 0.0045 - accuracy: 0.9993 - val_loss: 0.0000e+00 - val_accuracy: 0.9559
#
# Epoch 00028: val_loss improved from 0.00000 to 0.00000, saving model to best_weights_xception.h5
# Epoch 29/30
# 1566/1566 [==============================] - 1165s 744ms/step - loss: 0.0033 - accuracy: 0.9995 - val_loss: 1.7881e-08 - val_accuracy: 0.9057
#
# Epoch 00029: val_loss did not improve from 0.00000
# Epoch 30/30
# 1566/1566 [==============================] - 1167s 745ms/step - loss: 7.0268e-04 - accuracy: 0.9998 - val_loss: 0.0000e+00 - val_accuracy: 0.9385
#
# Epoch 00030: val_loss did not improve from 0.00000

# %% [markdown]
# Visualizing the model's training and validation loss and accuracy progression for every epoch...

# %%
# Initializing the subplot 
plt.subplots(1,2,figsize=(20,10))

# Plotting the model's training and validation loss progression for every completed epoch 
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss', linewidth=2, marker='o', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2, marker='^', color='red')

# Formatting axes and titles
plt.suptitle('Optimizer : Adam , Learning Rate: 0.0001', fontsize=20)
plt.ylabel('Loss', fontsize=18)
plt.xlabel('Epoch', fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Formatting legend
plt.legend(loc='upper right', fontsize=18)

# Plotting the training and validation accuracy changes for every epoch 
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy', linewidth=2, marker='o', color='blue')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2, marker='^', color='red')

# Formatting axes and titles
plt.ylabel('Accuracy', fontsize=18)
plt.xlabel('Epoch', fontsize=18)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14)

# Formatting legend
plt.legend(loc='lower right', fontsize=18)

# Display the plots
plt.show()

# %% [markdown]
# ## Model Evaluation
#
# In order to evaluate the `bestmodel`'s performance we will need to load in the `best_weights_xception.h5` saved by `ModelCheckpoint()`.

# %%
# Saving the CNN architecture as a JSON
modelarch_json = model.to_json()
with open("xception_asl.json","w") as json_file:
    json_file.write(modelarch_json)
    
# Initialize the 'bestmodel' using the weights saved with the ModelCheckpoint callback
bestmodel = model_from_json(modelarch_json)

# Loading the weights that resulted in the best validation accuracy during training 
bestmodel.load_weights("best_weights_xception.h5")

# Compile the bestmodel
bestmodel.compile(optimizer=optim, loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# The `bestmodel` that resulted from training will be evaluated via classification reports and confusion matrices normalized by the number of images for the given class.

# %%
# Creating axis labels for future sns.heatmaps 

# Getting the class names
categories = list(train_generator.class_indices.keys())

# Preficing classes with 'Predicted ' 
predicted_labels = list('Predicted '  + category for category in categories)

# Preficing classes with 'True '
true_labels = list('True ' + category for category in categories)

# Creating labels(indices) for model evaluation metrics 
eval_metrics = list(bestmodel.metrics_names)

# %% [markdown]
# **NOTE:** Unable to create a classification report or confusion matrix for train data as train_generator(shuffle=True) does not save the true classes

# %%
# Re-evaluating the best model's performance on the training data
train_eval = bestmodel.evaluate_generator(train_generator, steps=train_stepsize)

# Saving the results to a dataframe
df_train_eval = pd.DataFrame(list(train_eval), index=eval_metrics, columns=['Train'])

# Display the results
print(df_train_eval)
# Out:
#              Train
# loss      0.298505
# accuracy  0.993806

# %% [markdown]
# Thus, `bestmodel` achieved <b>99.4% accuracy</b> and <b><i> 0.2985</i></b> categorical crossentropy loss on the train dataset.
#
# -----
#
# ### Evaluating `bestmodel` Performance on the Validation Dataset
#
# First, we will acquire the model's predictions and save to variable `valid_predictions`.

# %%
# Getting bestmodel's predictions (as probabilities) on the validation images 
validation_probas = bestmodel.predict_generator(validation_generator, steps=valid_stepsize)

# Setting the model's class prediction as the class that received the highest probability for each image
valid_predictions = validation_probas.argmax(axis=1)

# Sanity check 
valid_predictions
# Out:
# array([ 0,  0,  0, ..., 28, 28, 28], dtype=int64)

# %% [markdown]
# Next, acquiring the images' true labels and saving to variable `valid_true`.

# %%
# Getting the true class labels for the validation data
valid_true = validation_generator.classes

# Sanity check 
valid_true
# Out:
# array([ 0,  0,  0, ..., 28, 28, 28])

# %% [markdown]
# Finally, we will compare `valid_predictions` with `valid_true` to acquire model accuracy, precision, recall, f1-scores and a confusion matrix.

# %%
# Evaluating bestmodel's performance on the validation data 
valid_eval = bestmodel.evaluate_generator(validation_generator, steps=valid_stepsize)

# Saving the results to a dataframe
df_valid_eval = pd.DataFrame(list(valid_eval), index=eval_metrics, columns=['Validation'])

# Display the results 
print(df_valid_eval)
# Out:
#           Validation
# loss        0.000000
# accuracy    0.953305

# %% [markdown]
# Thus, `bestmodel` achieved <b>95.3% accuracy</b> and <b><i> < 0.0001</i></b> categorical crossentropy loss on the validation dataset.

# %%
# Displaying the classification report for the validation set
print('Validation Classification Report\n \n', classification_report(valid_true, valid_predictions, target_names=categories))
# Out:
# Validation Classification Report
#
#                precision    recall  f1-score   support
#
#            A       0.99      1.00      1.00       240
#            B       1.00      1.00      1.00       240
#            C       0.97      1.00      0.99       240
#            D       1.00      0.98      0.99       240
#            E       0.98      1.00      0.99       240
#            F       1.00      0.97      0.99       240
#            G       1.00      1.00      1.00       240
#            H       1.00      0.97      0.98       240
#            I       1.00      0.96      0.98       240
#            J       1.00      0.93      0.97       240
#            K       1.00      0.98      0.99       240
#            L       1.00      1.00      1.00       240
#            M       1.00      1.00      1.00       240
#            N       1.00      0.67      0.80       240
#            O       1.00      0.93      0.97       240
#            P       1.00      0.93      0.96       240
#            Q       1.00      0.85      0.92       240
#            R       0.98      0.99      0.98       240
#            S       1.00      0.93      0.96       240
#            T       1.00      0.79      0.88       240
#            U       1.00      0.97      0.98       240
#            V       1.00      0.92      0.96       240
#            W       0.98      1.00      0.99       240
#            X       0.99      0.95      0.97       240
#            Y       0.96      1.00      0.98       240
#            Z       1.00      0.94      0.97       240
#          del       1.00      0.96      0.98       240
#      nothing       0.45      1.00      0.62       240
#        space       1.00      1.00      1.00       240
#
#     accuracy                           0.95      6960
#    macro avg       0.98      0.95      0.96      6960
# weighted avg       0.98      0.95      0.96      6960

# %% [markdown]
# `bestmodel` was better at classifying some classes over others when it came to the validation set. The model had poor precision when faced with images of the 'nothing' class and poor recall with the letter N.

# %%
# Creating a non-normalized confusion matrix for the validation set
valid_matrix = pd.DataFrame(confusion_matrix(valid_true, valid_predictions), columns=predicted_labels, index=true_labels)

# Display the matrix
valid_matrix
# Out:
#               Predicted A  Predicted B  Predicted C  Predicted D  Predicted E  \
# True A                240            0            0            0            0
# True B                  0          239            0            0            0
# True C                  0            0          240            0            0
# True D                  0            0            0          235            0
# True E                  0            0            0            0          240
# True F                  0            0            7            0            0
# True G                  0            0            0            0            0
# True H                  0            0            0            0            0
# True I                  0            0            0            0            6
# True J                  0            0            0            0            0
# True K                  0            0            0            0            0
# True L                  0            0            0            0            0
# True M                  0            0            0            0            0
# True N                  0            0            0            0            0
# True O                  0            0            0            0            0
# True P                  0            0            0            0            0
# True Q                  0            0            0            0            0
# True R                  0            0            0            0            0
# True S                  0            0            0            0            0
# True T                  2            0            0            0            0
# True U                  0            0            0            0            0
# True V                  0            0            0            0            0
# True W                  0            0            0            0            0
# True X                  0            0            0            0            0
# True Y                  0            0            0            0            0
# True Z                  0            0            0            0            0
# True del                0            0            0            0            0
# True nothing            0            0            0            0            0
# True space              0            0            0            0            0
#
#               Predicted F  Predicted G  Predicted H  Predicted I  Predicted J  \
# True A                  0            0            0            0            0
# True B                  0            0            0            0            0
# True C                  0            0            0            0            0
# True D                  0            0            0            0            0
# True E                  0            0            0            0            0
# True F                233            0            0            0            0
# True G                  0          240            0            0            0
# True H                  0            0          232            0            0
# True I                  0            0            0          230            0
# True J                  0            0            0            0          224
# True K                  0            0            0            0            0
# True L                  0            0            0            0            0
# True M                  0            0            0            0            0
# True N                  0            0            0            0            0
# True O                  0            0            0            0            0
# True P                  0            0            0            0            0
# True Q                  0            0            0            0            0
# True R                  0            0            0            0            0
# True S                  0            0            0            0            0
# True T                  0            0            0            0            0
# True U                  0            0            0            0            0
# True V                  0            0            1            0            0
# True W                  0            0            0            0            0
# True X                  0            0            0            0            0
# True Y                  0            0            0            0            0
# True Z                  0            0            0            0            0
# True del                0            0            0            0            0
# True nothing            0            0            0            0            0
# True space              0            0            0            0            0
#
#               ...  Predicted T  Predicted U  Predicted V  Predicted W  \
# True A        ...            0            0            0            0
# True B        ...            0            0            0            0
# True C        ...            0            0            0            0
# True D        ...            0            0            0            0
# True E        ...            0            0            0            0
# True F        ...            0            0            0            0
# True G        ...            0            0            0            0
# True H        ...            0            0            0            0
# True I        ...            0            0            0            0
# True J        ...            0            0            0            0
# True K        ...            0            0            0            0
# True L        ...            0            0            0            0
# True M        ...            0            0            0            0
# True N        ...            0            0            0            0
# True O        ...            0            0            0            0
# True P        ...            0            0            0            0
# True Q        ...            0            0            0            0
# True R        ...            0            0            0            0
# True S        ...            0            0            0            0
# True T        ...          189            0            0            0
# True U        ...            0          232            0            0
# True V        ...            0            1          221            4
# True W        ...            0            0            0          239
# True X        ...            0            0            0            0
# True Y        ...            0            0            0            0
# True Z        ...            0            0            0            0
# True del      ...            0            0            0            0
# True nothing  ...            0            0            0            0
# True space    ...            0            0            0            0
#
#               Predicted X  Predicted Y  Predicted Z  Predicted del  \
# True A                  0            0            0              0
# True B                  0            0            0              0
# True C                  0            0            0              0
# True D                  0            0            0              0
# True E                  0            0            0              0
# True F                  0            0            0              0
# True G                  0            0            0              0
# True H                  0            0            0              0
# True I                  0            0            0              0
# True J                  0            0            0              0
# True K                  0            0            0              0
# True L                  0            0            0              0
# True M                  0            0            0              0
# True N                  0            0            0              0
# True O                  0            0            0              0
# True P                  0            0            0              0
# True Q                  0            0            0              0
# True R                  0            0            0              0
# True S                  2            0            0              0
# True T                  0           11            0              0
# True U                  0            0            0              0
# True V                  0            0            0              0
# True W                  0            0            0              0
# True X                229            0            0              0
# True Y                  0          240            0              0
# True Z                  0            0          225              0
# True del                0            0            0            231
# True nothing            0            0            0              0
# True space              0            0            0              0
#
#               Predicted nothing  Predicted space
# True A                        0                0
# True B                        1                0
# True C                        0                0
# True D                        5                0
# True E                        0                0
# True F                        0                0
# True G                        0                0
# True H                        8                0
# True I                        3                0
# True J                       16                0
# True K                        5                0
# True L                        0                0
# True M                        0                0
# True N                       79                0
# True O                       16                0
# True P                       17                0
# True Q                       35                0
# True R                        3                0
# True S                       15                0
# True T                       38                0
# True U                        3                0
# True V                       13                0
# True W                        1                0
# True X                       11                0
# True Y                        0                0
# True Z                       15                0
# True del                      9                0
# True nothing                240                0
# True space                    0              240
#
# [29 rows x 29 columns]

# %%
# Plotting the normalized confusion matrix (proportion of predictions by class) as a heatmap

# Increasing fontsize
sns.set(font_scale=1.2)

# Creating the plot
plt.figure(figsize=(15,15))
sns.heatmap(round(valid_matrix/valid_matrix.sum(axis=1)[:,np.newaxis],2), cmap='Blues', annot=True, linewidths=.5, linecolor='black')

# Formatting the title 
plt.title('Normalized Confusion Matrix: Validation Data', fontsize=20)

# Display the normalized confusion matrix
plt.show()

# %% [markdown]
# Based on the non-normalized and normalized confusion matrices, we can see that `bestmodel` was mistakenly predicting some letters, especially N but T and Q were right up there as well, as 'nothing.'
#
# -----
#
# ### Evaluating `bestmodel` Performance on the Test Dataset
#
# Similar as above, we will first acquire the model's predictions and saving to variable `test_predictions`.

# %%
# Getting bestmodel's predictions (as probabilities) on the test set 
test_probas = bestmodel.predict_generator(test_generator, steps=test_stepsize)

# Setting the model's class prediction as the class that received the highest probability for each image
test_predictions = test_probas.argmax(axis=1)

# Sanity check 
test_predictions
# Out:
# array([ 0,  0,  0, ..., 28, 28, 28], dtype=int64)

# %% [markdown]
# Next, saving the true classes of the test images to the variable `test_true`.

# %%
# Getting the true class labels for the test set
test_true = test_generator.classes

# Sanity check 
test_true
# Out:
# array([ 0,  0,  0, ..., 28, 28, 28])

# %% [markdown]
# Finally, we will compare `test_predictions` with `test_true` to acquire model accuracy, precision, recall, f1-scores and confusion matrices to evalute model performance on the test set.

# %%
# Evaluating the best model's performance on the test data 
test_eval = bestmodel.evaluate_generator(test_generator, steps=test_stepsize)

# Saving the results to a dataframe 
df_test_eval = pd.DataFrame(list(test_eval), index=eval_metrics, columns=['Test'])

# Display the results
print(df_test_eval)
# Out:
#               Test
# loss      0.000000
# accuracy  0.989713

# %% [markdown]
# When faced with images the model had never seen before (test set), we see a higher accuracy when compared to the validation set. `bestmodel` achieved <b>99.0% accuracy</b> and <b><i>< 0.0001</i></b> categorical crossentropy loss on the test set.

# %%
# Displaying the classification report for the test set
print('Test Classification Report\n \n', classification_report(test_true, test_predictions, target_names=categories))
# Out:
# Test Classification Report
#
#                precision    recall  f1-score   support
#
#            A       1.00      1.00      1.00       600
#            B       1.00      0.99      1.00       600
#            C       1.00      0.99      1.00       600
#            D       1.00      0.99      1.00       600
#            E       1.00      0.99      0.99       600
#            F       1.00      1.00      1.00       600
#            G       1.00      0.99      0.99       600
#            H       1.00      0.99      1.00       600
#            I       1.00      0.99      1.00       600
#            J       1.00      0.98      0.99       600
#            K       1.00      1.00      1.00       600
#            L       1.00      1.00      1.00       600
#            M       1.00      0.98      0.99       600
#            N       1.00      0.94      0.97       600
#            O       1.00      0.99      0.99       600
#            P       1.00      0.98      0.99       600
#            Q       1.00      0.99      0.99       600
#            R       1.00      0.99      1.00       600
#            S       0.99      0.99      0.99       600
#            T       1.00      0.97      0.99       600
#            U       1.00      0.99      0.99       600
#            V       1.00      0.99      0.99       600
#            W       1.00      1.00      1.00       600
#            X       1.00      0.99      0.99       600
#            Y       0.99      0.99      0.99       600
#            Z       1.00      0.99      1.00       600
#          del       1.00      0.99      1.00       600
#      nothing       0.79      1.00      0.88       600
#        space       1.00      0.99      1.00       600
#
#     accuracy                           0.99     17400
#    macro avg       0.99      0.99      0.99     17400
# weighted avg       0.99      0.99      0.99     17400

# %% [markdown]
# Again with the test set we can see that `bestmodel` also had the hardest time precisely classifying images of the 'nothing' class.

# %%
# Non-normalized confusion matrix for the test data
test_matrix = pd.DataFrame(confusion_matrix(test_true, test_predictions), columns=predicted_labels, index=true_labels)

# Plotting a normalized confusion matrix for the test data as a heatmap 
sns.set(font_scale=1.2)
plt.figure(figsize=(15,15))
sns.heatmap(round(test_matrix/test_matrix.sum(axis=1)[:,np.newaxis],2), cmap='Blues', annot=True, linewidths=.5, linecolor='black')
plt.title('Normalized Confusion Matrix: Test Data', fontsize=20)
plt.show()

# %% [markdown]
# Based on the non-normalized and normalized confusion matrices, the Xception model weights that resulted in the best validation accuracy during training (i.e., `best_weights_xception.h5`) proved successful at predicting the classes of images it had never seen before (i.e., test set images).
#
# **However, the test images were very similar to the images that the Xception CNN was trained on, which may account for the high scores we are seeing. It should also be noted that the model has a slight bias towards predicting the 'nothing' class based on its lower precision scores.**
#
# -----
#
# Keeping in mind that the final goal is to classify letters of the ASL alphabet from images taken in real-time, the `best_weights_xception.h5` obtained from the training of Xception in this notebook will undergo additional evaluation of:
#
# **Predicting on images taken from live webcam in the subsequent notebook** `real-time_test.ipynb`.
